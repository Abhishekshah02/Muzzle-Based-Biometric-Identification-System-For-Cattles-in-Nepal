# %% [markdown]
# For dataset 1

# %%
#!/usr/bin/env python3
"""
train_arcface_finetune_true.py
True ArcFace fine-tuning with ResNet50 backbone,
Top-1 and Top-5 metrics, and plotted training curves.
"""
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
from tensorflow.keras import layers
from sklearn.utils.class_weight import compute_class_weight



# ==============================
# USER CONFIG
# ==============================
OUTPUT_DIR = r"C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify"
train_dir  = r"C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\preprocess_dataset_1\train"
val_dir    = r"C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\preprocess_dataset_1\val"


PK_P, PK_K = 16, 4
IMG_SIZE   = (224, 224)
BATCH_SIZE = PK_P * PK_K

# ==============================
# Dataset
# ==============================
train_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.03),
    layers.RandomZoom(0.05),
    layers.RandomContrast(0.1)
])


def preprocess_rgb(x, y):
    # convert grayscale -> RGB if needed
    x = tf.image.grayscale_to_rgb(x) if x.shape[-1] == 1 else x
    return x, y

train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir, labels='inferred', label_mode='int',
    image_size=IMG_SIZE, batch_size=BATCH_SIZE, shuffle=True,
    color_mode='rgb'  # <-- ensure it's loaded as 3-channel
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    val_dir, labels='inferred', label_mode='int',
    image_size=IMG_SIZE, batch_size=BATCH_SIZE, shuffle=False,
    color_mode='rgb'
)

class_names = train_ds.class_names
num_classes = len(class_names)
print(f"Found {num_classes} unique classes.")


AUTOTUNE = tf.data.AUTOTUNE
train_ds = (
    train_ds
    .map(preprocess_rgb)
    .map(lambda x, y: (train_augment(x, training=True), y))
    .map(lambda x, y: ((x, y), y))
    .prefetch(AUTOTUNE)   # ✅ at the END
)

val_ds = (
    val_ds
    .map(preprocess_rgb)
    .map(lambda x, y: ((x, y), y))
    .prefetch(AUTOTUNE)   # ✅ at the END
)


# --- compute all labels from the training dataset ---
all_labels = np.array([label.numpy() for (x, y), label in train_ds.unbatch()])


# --- compute class weights automatically ---
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(num_classes),
    y=all_labels
)

# --- convert to dictionary for Keras ---
class_weights = dict(enumerate(class_weights))


# ==============================
# 🧠 Custom ArcFace Layer
# ==============================
class ArcFace(tf.keras.layers.Layer):
    def __init__(self, num_classes, s=30.0, m=0.35, **kwargs):
        super().__init__(**kwargs)
        self.num_classes = num_classes
        self.s = s
        self.m = m

    def build(self, input_shape):
        self.W = self.add_weight(
            name='W',
            shape=(int(input_shape[-1]), self.num_classes),
            initializer='glorot_uniform',
            trainable=True
        )

    def call(self, inputs, labels):
        x = tf.nn.l2_normalize(inputs, axis=1)
        W = tf.nn.l2_normalize(self.W, axis=0)
        cos_theta = tf.matmul(x, W)
        cos_theta = tf.clip_by_value(cos_theta, -1.0, 1.0)
        theta = tf.acos(cos_theta)
        selected = tf.gather_nd(theta, tf.stack([tf.range(tf.shape(labels)[0]), labels], axis=1))
        theta_y_m = selected + self.m
        mask = tf.one_hot(labels, depth=self.num_classes)
        cos_theta_m = tf.cos(theta_y_m)
        logits = cos_theta * (1 - mask) + cos_theta_m[:, None] * mask
        logits *= self.s
        return logits

# ==============================
# Build True ArcFace Model
# ==============================
base_model = tf.keras.applications.ResNet50(
    include_top=False, weights='imagenet',
    pooling='avg', input_shape=IMG_SIZE + (3,))
base_model.trainable = False

inputs = tf.keras.Input(shape=IMG_SIZE + (3,))
labels = tf.keras.Input(shape=(), dtype=tf.int32)
x = tf.keras.applications.resnet50.preprocess_input(inputs)
x = base_model(x, training=False)
x = tf.keras.layers.Dense(512, activation=None, name="embedding")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.25)(x)
logits = ArcFace(num_classes)(x, labels)
model = tf.keras.Model(inputs=[inputs, labels], outputs=logits, name="arcface_resnet50")

# ==============================
# Callbacks
# ==============================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(OUTPUT_DIR, "1_adamW_best_arcface_model.keras"),
        monitor="val_top1_acc", save_best_only=True, mode="max", verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_top1_acc", factor=0.5, patience=3, verbose=1),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_top1_acc", patience=6, restore_best_weights=True, verbose=1)
]


# ==============================================
# 🧱 STAGE 1 — Freeze backbone (stabilize ArcFace head)
# ==============================================

initial_lr = 2e-4
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile(
    optimizer=tf.keras.optimizers.AdamW(initial_lr, weight_decay=1e-4),
    loss=loss_fn,
    metrics=[
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=1, name="top1_acc"),
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name="top5_acc")
    ]
)


# ==============================
# Train
# ==============================
EPOCHS_1 = 15
history1 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=EPOCHS_1, callbacks=callbacks
    ,class_weight=class_weights
)



# ==============================================
# 🔓 STAGE 2 — Unfreeze backbone (fine-tune entire model)
# ==============================================

print("\n🔓 Stage 2: Unfreezing backbone and fine-tuning entire model...")
N_UNFREEZE = 50  # try 30–70 depending on dataset size

# Freeze all layers first
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze last N layers (but skip BN layers)
for layer in base_model.layers[-N_UNFREEZE:]:
    if not isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = True

# 🔒 Keep all BatchNorm layers frozen globally
for layer in base_model.layers:
    if isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = False


model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-5, weight_decay=5e-5),
    loss=loss_fn,
    metrics=[
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=1, name="top1_acc"),
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name="top5_acc")
    ]
)

EPOCHS_2 = 25
total_epochs = EPOCHS_1 + EPOCHS_2

history2 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=total_epochs,
    initial_epoch=EPOCHS_1,
    callbacks=callbacks ,class_weight=class_weights
)

# Combine histories for full plot
def merge_histories(h1, h2):
    # handle both Keras History objects and dicts
    h1 = h1.history if hasattr(h1, "history") else h1
    h2 = h2.history if hasattr(h2, "history") else h2

    hist = {}
    for k in h1.keys():
        hist[k] = h1[k] + h2[k]
    return hist

full_history = merge_histories(history1, history2)



# ==============================
# Plot training graphs
# ==============================
def plot_history(history_dict, out_dir):
    epochs = np.arange(1, len(history_dict['loss']) + 1)
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.plot(epochs, history_dict['loss'], label='train_loss')
    plt.plot(epochs, history_dict['val_loss'], label='val_loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.grid(True)
    plt.subplot(1,2,2)
    plt.plot(epochs, history_dict['top1_acc'], label='train_top1')
    plt.plot(epochs, history_dict['val_top1_acc'], label='val_top1')
    plt.plot(epochs, history_dict['top5_acc'], label='train_top5', linestyle='--')
    plt.plot(epochs, history_dict['val_top5_acc'], label='val_top5', linestyle='--')
    plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.grid(True)
    plt.tight_layout()
    plot_path = os.path.join(out_dir, "1_adamW_training_history.png")
    plt.savefig(plot_path, dpi=200)
    plt.close()
    print(f"[save] training plot: {plot_path}")

plot_history(full_history, OUTPUT_DIR)

print("\n✅ Training completed. Best model saved as '1_adamW_best_arcface_model.keras'.")
print(f"Training history plot saved to: {os.path.join(OUTPUT_DIR, '1_adamW_training_history.png')}")
# Out:
# Found 4606 files belonging to 455 classes.
# Found 550 files belonging to 455 classes.
# Found 455 unique classes.
# Epoch 1/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 16.6264 - top1_acc: 0.0000e+00 - top5_acc: 0.0000e+00
# Epoch 1: val_top1_acc improved from None to 0.00000, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 248s 3s/step - loss: 16.1183 - top1_acc: 0.0000e+00 - top5_acc: 0.0000e+00 - val_loss: 14.7722 - val_top1_acc: 0.0000e+00 - val_top5_acc: 0.0000e+00 - learning_rate: 2.0000e-04
# Epoch 2/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 14.2412 - top1_acc: 0.0000e+00 - top5_acc: 0.0000e+00
# Epoch 2: val_top1_acc did not improve from 0.00000
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 252s 4s/step - loss: 13.9884 - top1_acc: 0.0000e+00 - top5_acc: 0.0000e+00 - val_loss: 12.8116 - val_top1_acc: 0.0000e+00 - val_top5_acc: 0.0000e+00 - learning_rate: 2.0000e-04
# Epoch 3/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 12.5921 - top1_acc: 0.0000e+00 - top5_acc: 7.8475e-05
# Epoch 3: val_top1_acc did not improve from 0.00000
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 242s 3s/step - loss: 12.3361 - top1_acc: 0.0000e+00 - top5_acc: 2.1711e-04 - val_loss: 11.3261 - val_top1_acc: 0.0000e+00 - val_top5_acc: 0.0018 - learning_rate: 2.0000e-04
# Epoch 4/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 11.1451 - top1_acc: 1.8389e-05 - top5_acc: 0.0014
# Epoch 4: val_top1_acc improved from 0.00000 to 0.00545, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 249s 3s/step - loss: 10.9971 - top1_acc: 4.3422e-04 - top5_acc: 0.0037 - val_loss: 10.1555 - val_top1_acc: 0.0055 - val_top5_acc: 0.0236 - learning_rate: 2.0000e-04
# Epoch 5/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 9.9772 - top1_acc: 0.0051 - top5_acc: 0.0164
# Epoch 5: val_top1_acc improved from 0.00545 to 0.02364, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 252s 3s/step - loss: 9.8396 - top1_acc: 0.0074 - top5_acc: 0.0226 - val_loss: 9.1602 - val_top1_acc: 0.0236 - val_top5_acc: 0.0636 - learning_rate: 2.0000e-04
# Epoch 6/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 8.8753 - top1_acc: 0.0249 - top5_acc: 0.0621
# Epoch 6: val_top1_acc improved from 0.02364 to 0.06909, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 247s 3s/step - loss: 8.8176 - top1_acc: 0.0265 - top5_acc: 0.0651 - val_loss: 8.3508 - val_top1_acc: 0.0691 - val_top5_acc: 0.1309 - learning_rate: 2.0000e-04
# Epoch 7/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 8.0358 - top1_acc: 0.0566 - top5_acc: 0.1171
# Epoch 7: val_top1_acc improved from 0.06909 to 0.10182, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 251s 3s/step - loss: 7.9412 - top1_acc: 0.0623 - top5_acc: 0.1251 - val_loss: 7.7486 - val_top1_acc: 0.1018 - val_top5_acc: 0.2018 - learning_rate: 2.0000e-04
# Epoch 8/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 7.2703 - top1_acc: 0.0831 - top5_acc: 0.1738
# Epoch 8: val_top1_acc improved from 0.10182 to 0.16364, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 243s 3s/step - loss: 7.1747 - top1_acc: 0.0997 - top5_acc: 0.1917 - val_loss: 7.0552 - val_top1_acc: 0.1636 - val_top5_acc: 0.2873 - learning_rate: 2.0000e-04
# Epoch 9/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.5857 - top1_acc: 0.1389 - top5_acc: 0.2573
# Epoch 9: val_top1_acc improved from 0.16364 to 0.19455, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 245s 3s/step - loss: 6.5431 - top1_acc: 0.1452 - top5_acc: 0.2644 - val_loss: 6.6246 - val_top1_acc: 0.1945 - val_top5_acc: 0.3455 - learning_rate: 2.0000e-04
# Epoch 10/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 5.9611 - top1_acc: 0.1960 - top5_acc: 0.3297
# Epoch 10: val_top1_acc improved from 0.19455 to 0.24182, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 252s 3s/step - loss: 5.9703 - top1_acc: 0.1904 - top5_acc: 0.3317 - val_loss: 6.1971 - val_top1_acc: 0.2418 - val_top5_acc: 0.4018 - learning_rate: 2.0000e-04
# Epoch 11/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 5.5470 - top1_acc: 0.2424 - top5_acc: 0.3881
# Epoch 11: val_top1_acc improved from 0.24182 to 0.26909, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 235s 3s/step - loss: 5.4805 - top1_acc: 0.2453 - top5_acc: 0.4012 - val_loss: 5.9703 - val_top1_acc: 0.2691 - val_top5_acc: 0.4309 - learning_rate: 2.0000e-04
# Epoch 12/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 5.1394 - top1_acc: 0.2830 - top5_acc: 0.4455
# Epoch 12: val_top1_acc improved from 0.26909 to 0.30727, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 234s 3s/step - loss: 5.1242 - top1_acc: 0.2948 - top5_acc: 0.4509 - val_loss: 5.7172 - val_top1_acc: 0.3073 - val_top5_acc: 0.4636 - learning_rate: 2.0000e-04
# Epoch 13/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.7670 - top1_acc: 0.3212 - top5_acc: 0.4973
# Epoch 13: val_top1_acc improved from 0.30727 to 0.35455, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 233s 3s/step - loss: 4.7589 - top1_acc: 0.3333 - top5_acc: 0.5000 - val_loss: 5.4492 - val_top1_acc: 0.3545 - val_top5_acc: 0.4927 - learning_rate: 2.0000e-04
# Epoch 14/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.4935 - top1_acc: 0.3629 - top5_acc: 0.5223
# Epoch 14: val_top1_acc improved from 0.35455 to 0.37455, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 233s 3s/step - loss: 4.4796 - top1_acc: 0.3654 - top5_acc: 0.5287 - val_loss: 5.2781 - val_top1_acc: 0.3745 - val_top5_acc: 0.5109 - learning_rate: 2.0000e-04
# Epoch 15/15
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.2007 - top1_acc: 0.4019 - top5_acc: 0.5609
# Epoch 15: val_top1_acc improved from 0.37455 to 0.38545, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 231s 3s/step - loss: 4.2003 - top1_acc: 0.4038 - top5_acc: 0.5647 - val_loss: 5.1244 - val_top1_acc: 0.3855 - val_top5_acc: 0.5218 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 15.
#
# 🔓 Stage 2: Unfreezing backbone and fine-tuning entire model...
# Epoch 16/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 3.8366 - top1_acc: 0.4471 - top5_acc: 0.6084
# Epoch 16: val_top1_acc improved from 0.38545 to 0.44000, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 344s 5s/step - loss: 3.7170 - top1_acc: 0.4657 - top5_acc: 0.6238 - val_loss: 4.7301 - val_top1_acc: 0.4400 - val_top5_acc: 0.5836 - learning_rate: 1.0000e-05
# Epoch 17/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 3.4433 - top1_acc: 0.5108 - top5_acc: 0.6523
# Epoch 17: val_top1_acc improved from 0.44000 to 0.44727, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 330s 5s/step - loss: 3.3985 - top1_acc: 0.5137 - top5_acc: 0.6598 - val_loss: 4.5917 - val_top1_acc: 0.4473 - val_top5_acc: 0.5982 - learning_rate: 1.0000e-05
# Epoch 18/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 3.2455 - top1_acc: 0.5283 - top5_acc: 0.6747
# Epoch 18: val_top1_acc improved from 0.44727 to 0.46364, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 327s 5s/step - loss: 3.2242 - top1_acc: 0.5365 - top5_acc: 0.6819 - val_loss: 4.5093 - val_top1_acc: 0.4636 - val_top5_acc: 0.6291 - learning_rate: 1.0000e-05
# Epoch 19/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 3.1078 - top1_acc: 0.5477 - top5_acc: 0.6847
# Epoch 19: val_top1_acc improved from 0.46364 to 0.47091, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 330s 5s/step - loss: 3.0807 - top1_acc: 0.5575 - top5_acc: 0.6932 - val_loss: 4.4302 - val_top1_acc: 0.4709 - val_top5_acc: 0.6455 - learning_rate: 1.0000e-05
# Epoch 20/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.9456 - top1_acc: 0.5701 - top5_acc: 0.7069
# Epoch 20: val_top1_acc improved from 0.47091 to 0.48545, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 330s 5s/step - loss: 2.9256 - top1_acc: 0.5803 - top5_acc: 0.7128 - val_loss: 4.3343 - val_top1_acc: 0.4855 - val_top5_acc: 0.6600 - learning_rate: 1.0000e-05
# Epoch 21/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.8437 - top1_acc: 0.5944 - top5_acc: 0.7177
# Epoch 21: val_top1_acc improved from 0.48545 to 0.49273, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 330s 5s/step - loss: 2.8206 - top1_acc: 0.5999 - top5_acc: 0.7236 - val_loss: 4.2804 - val_top1_acc: 0.4927 - val_top5_acc: 0.6600 - learning_rate: 1.0000e-05
# Epoch 22/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.7237 - top1_acc: 0.5977 - top5_acc: 0.7303
# Epoch 22: val_top1_acc improved from 0.49273 to 0.50000, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 329s 5s/step - loss: 2.7028 - top1_acc: 0.6099 - top5_acc: 0.7358 - val_loss: 4.2369 - val_top1_acc: 0.5000 - val_top5_acc: 0.6745 - learning_rate: 1.0000e-05
# Epoch 23/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.5969 - top1_acc: 0.6219 - top5_acc: 0.7456
# Epoch 23: val_top1_acc improved from 0.50000 to 0.53091, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 328s 5s/step - loss: 2.6088 - top1_acc: 0.6227 - top5_acc: 0.7432 - val_loss: 4.1547 - val_top1_acc: 0.5309 - val_top5_acc: 0.6855 - learning_rate: 1.0000e-05
# Epoch 24/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.4440 - top1_acc: 0.6479 - top5_acc: 0.7658
# Epoch 24: val_top1_acc did not improve from 0.53091
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 331s 5s/step - loss: 2.4878 - top1_acc: 0.6381 - top5_acc: 0.7599 - val_loss: 4.0956 - val_top1_acc: 0.5309 - val_top5_acc: 0.7018 - learning_rate: 1.0000e-05
# Epoch 25/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.4025 - top1_acc: 0.6479 - top5_acc: 0.7657
# Epoch 25: val_top1_acc improved from 0.53091 to 0.54000, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 337s 5s/step - loss: 2.3998 - top1_acc: 0.6518 - top5_acc: 0.7681 - val_loss: 4.0635 - val_top1_acc: 0.5400 - val_top5_acc: 0.7055 - learning_rate: 1.0000e-05
# Epoch 26/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.3251 - top1_acc: 0.6545 - top5_acc: 0.7699
# Epoch 26: val_top1_acc improved from 0.54000 to 0.55091, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 329s 5s/step - loss: 2.3177 - top1_acc: 0.6613 - top5_acc: 0.7753 - val_loss: 4.0046 - val_top1_acc: 0.5509 - val_top5_acc: 0.7073 - learning_rate: 1.0000e-05
# Epoch 27/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.2011 - top1_acc: 0.6794 - top5_acc: 0.7828
# Epoch 27: val_top1_acc improved from 0.55091 to 0.55636, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 329s 5s/step - loss: 2.2454 - top1_acc: 0.6780 - top5_acc: 0.7799 - val_loss: 3.9640 - val_top1_acc: 0.5564 - val_top5_acc: 0.7164 - learning_rate: 1.0000e-05
# Epoch 28/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.1362 - top1_acc: 0.6831 - top5_acc: 0.7921
# Epoch 28: val_top1_acc improved from 0.55636 to 0.55818, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 329s 5s/step - loss: 2.1552 - top1_acc: 0.6861 - top5_acc: 0.7907 - val_loss: 3.9382 - val_top1_acc: 0.5582 - val_top5_acc: 0.7182 - learning_rate: 1.0000e-05
# Epoch 29/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.0576 - top1_acc: 0.6982 - top5_acc: 0.7979
# Epoch 29: val_top1_acc improved from 0.55818 to 0.56545, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 329s 5s/step - loss: 2.0908 - top1_acc: 0.6963 - top5_acc: 0.7931 - val_loss: 3.8812 - val_top1_acc: 0.5655 - val_top5_acc: 0.7236 - learning_rate: 1.0000e-05
# Epoch 30/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.9897 - top1_acc: 0.6968 - top5_acc: 0.8020
# Epoch 30: val_top1_acc did not improve from 0.56545
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 327s 5s/step - loss: 2.0156 - top1_acc: 0.7021 - top5_acc: 0.8031 - val_loss: 3.8828 - val_top1_acc: 0.5636 - val_top5_acc: 0.7309 - learning_rate: 1.0000e-05
# Epoch 31/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.9214 - top1_acc: 0.7155 - top5_acc: 0.8092
# Epoch 31: val_top1_acc improved from 0.56545 to 0.57818, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 329s 5s/step - loss: 1.9507 - top1_acc: 0.7152 - top5_acc: 0.8100 - val_loss: 3.8306 - val_top1_acc: 0.5782 - val_top5_acc: 0.7345 - learning_rate: 1.0000e-05
# Epoch 32/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.8431 - top1_acc: 0.7294 - top5_acc: 0.8209
# Epoch 32: val_top1_acc improved from 0.57818 to 0.58364, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 326s 5s/step - loss: 1.8699 - top1_acc: 0.7267 - top5_acc: 0.8168 - val_loss: 3.8137 - val_top1_acc: 0.5836 - val_top5_acc: 0.7400 - learning_rate: 1.0000e-05
# Epoch 33/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.8054 - top1_acc: 0.7282 - top5_acc: 0.8189
# Epoch 33: val_top1_acc did not improve from 0.58364
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 325s 5s/step - loss: 1.7885 - top1_acc: 0.7327 - top5_acc: 0.8239 - val_loss: 3.8082 - val_top1_acc: 0.5836 - val_top5_acc: 0.7345 - learning_rate: 1.0000e-05
# Epoch 34/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.7228 - top1_acc: 0.7377 - top5_acc: 0.8283
# Epoch 34: val_top1_acc improved from 0.58364 to 0.59091, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 328s 5s/step - loss: 1.7258 - top1_acc: 0.7423 - top5_acc: 0.8300 - val_loss: 3.7518 - val_top1_acc: 0.5909 - val_top5_acc: 0.7309 - learning_rate: 1.0000e-05
# Epoch 35/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.6616 - top1_acc: 0.7505 - top5_acc: 0.8361
# Epoch 35: val_top1_acc did not improve from 0.59091
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 328s 5s/step - loss: 1.6768 - top1_acc: 0.7499 - top5_acc: 0.8324 - val_loss: 3.7536 - val_top1_acc: 0.5891 - val_top5_acc: 0.7382 - learning_rate: 1.0000e-05
# Epoch 36/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.6350 - top1_acc: 0.7492 - top5_acc: 0.8361
# Epoch 36: val_top1_acc improved from 0.59091 to 0.60364, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 328s 5s/step - loss: 1.6325 - top1_acc: 0.7566 - top5_acc: 0.8406 - val_loss: 3.7113 - val_top1_acc: 0.6036 - val_top5_acc: 0.7345 - learning_rate: 1.0000e-05
# Epoch 37/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.5598 - top1_acc: 0.7674 - top5_acc: 0.8527
# Epoch 37: val_top1_acc improved from 0.60364 to 0.61818, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 333s 5s/step - loss: 1.5705 - top1_acc: 0.7664 - top5_acc: 0.8491 - val_loss: 3.6807 - val_top1_acc: 0.6182 - val_top5_acc: 0.7455 - learning_rate: 1.0000e-05
# Epoch 38/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.5402 - top1_acc: 0.7715 - top5_acc: 0.8505
# Epoch 38: val_top1_acc did not improve from 0.61818
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 326s 5s/step - loss: 1.5191 - top1_acc: 0.7727 - top5_acc: 0.8513 - val_loss: 3.6765 - val_top1_acc: 0.6164 - val_top5_acc: 0.7436 - learning_rate: 1.0000e-05
# Epoch 39/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.4821 - top1_acc: 0.7775 - top5_acc: 0.8527
# Epoch 39: val_top1_acc improved from 0.61818 to 0.62000, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 329s 5s/step - loss: 1.4816 - top1_acc: 0.7764 - top5_acc: 0.8554 - val_loss: 3.6464 - val_top1_acc: 0.6200 - val_top5_acc: 0.7473 - learning_rate: 1.0000e-05
# Epoch 40/40
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.4199 - top1_acc: 0.7813 - top5_acc: 0.8641
# Epoch 40: val_top1_acc improved from 0.62000 to 0.62364, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 328s 5s/step - loss: 1.4239 - top1_acc: 0.7814 - top5_acc: 0.8643 - val_loss: 3.6523 - val_top1_acc: 0.6236 - val_top5_acc: 0.7400 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 40.
# [save] training plot: C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_training_history.png
#
# ✅ Training completed. Best model saved as '1_adamW_best_arcface_model.keras'.
# Training history plot saved to: C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_training_history.png

# %% [markdown]
# Testing

# %%
#!/usr/bin/env python3
"""
evaluate_arcface_metrics.py
Loads ArcFace-trained model, extracts embeddings,
and computes Top-K, ROC, EER, Balanced Accuracy, F1, and Recall on TEST dataset.
"""

import tensorflow as tf
import numpy as np
import os
from sklearn.metrics import roc_curve, auc, f1_score, balanced_accuracy_score, recall_score
import matplotlib.pyplot as plt

# ==============================
# USER CONFIG
# ==============================
MODEL_PATH = r"C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras"
test_dir   = r"C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\preprocess_dataset_1\test"
IMG_SIZE   = (224, 224)
BATCH_SIZE = 32

# ==============================
# Load dataset
# ==============================
def preprocess_rgb(x, y):
    x = tf.image.grayscale_to_rgb(x) if x.shape[-1] == 1 else x
    return x, y

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir, labels='inferred', label_mode='int',
    image_size=IMG_SIZE, batch_size=BATCH_SIZE, shuffle=False, color_mode='rgb'
)
class_names = test_ds.class_names
num_classes = len(class_names)

AUTOTUNE = tf.data.AUTOTUNE
test_ds = test_ds.map(preprocess_rgb).prefetch(AUTOTUNE)

# ==============================
# Load full ArcFace model
# ==============================
print(f"[INFO] Loading trained ArcFace model from: {MODEL_PATH}")
# ==============================
# 🧠 ArcFace layer (same as training)
# ==============================
import tensorflow as tf

class ArcFace(tf.keras.layers.Layer):
    def __init__(self, num_classes, s=30.0, m=0.5, **kwargs):
        super().__init__(**kwargs)
        self.num_classes = num_classes
        self.s = s
        self.m = m

    def build(self, input_shape):
        self.W = self.add_weight(
            name='W',
            shape=(int(input_shape[-1]), self.num_classes),
            initializer='glorot_uniform',
            trainable=True
        )

    def call(self, inputs, labels):
        x = tf.nn.l2_normalize(inputs, axis=1)
        W = tf.nn.l2_normalize(self.W, axis=0)
        cos_theta = tf.matmul(x, W)
        cos_theta = tf.clip_by_value(cos_theta, -1.0, 1.0)
        theta = tf.acos(cos_theta)
        selected = tf.gather_nd(theta, tf.stack([tf.range(tf.shape(labels)[0]), labels], axis=1))
        theta_y_m = selected + self.m
        mask = tf.one_hot(labels, depth=self.num_classes)
        cos_theta_m = tf.cos(theta_y_m)
        logits = cos_theta * (1 - mask) + cos_theta_m[:, None] * mask
        logits *= self.s
        return logits
 # import your ArcFace layer definition
full_model = tf.keras.models.load_model(MODEL_PATH, custom_objects={"ArcFace": ArcFace})

# ==============================
# Build inference (embedding) model
# ==============================
from tensorflow.keras.models import Model

# Full loaded model
full_model = tf.keras.models.load_model(MODEL_PATH, custom_objects={"ArcFace": ArcFace})

# Build embedding model: input = image, output = batch normalization (embedding)
embedding_model = Model(
    inputs=full_model.input[0],                        # image input only
    outputs=full_model.get_layer("batch_normalization_2").output
)


# ==============================
# Get predictions
# ==============================
y_true = []
embeddings = []
for batch_x, batch_y in test_ds:
    emb = embedding_model(batch_x, training=False)
    embeddings.append(emb.numpy())
    y_true.append(batch_y.numpy())

embeddings = np.concatenate(embeddings)
y_true = np.concatenate(y_true)

# Compute cosine similarities as logits (simple classification)
W = full_model.get_layer("arc_face").W.numpy()  # ArcFace class weights
W = W / np.linalg.norm(W, axis=0, keepdims=True)
emb_norm = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)
logits = np.dot(emb_norm, W)

y_pred = np.argmax(logits, axis=1)
y_score = tf.nn.softmax(logits, axis=1).numpy()

# ==============================
# Compute metrics
# ==============================
# Top-1 & Top-5
top1 = np.mean(np.equal(y_true, np.argmax(y_score, axis=1)))
top5 = np.mean([y_true[i] in np.argsort(y_score[i])[-5:] for i in range(len(y_true))])

# ROC & AUC (macro average)
fpr, tpr, _ = roc_curve(tf.keras.utils.to_categorical(y_true, num_classes).ravel(),
                        y_score.ravel())
roc_auc = auc(fpr, tpr)

# EER
fnr = 1 - tpr
eer_threshold = fpr[np.nanargmin(np.absolute((fnr - fpr)))]
eer = fpr[np.nanargmin(np.absolute((fnr - fpr)))]

# Other metrics
bal_acc = balanced_accuracy_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average=None)

# ==============================
# Print metrics
# ==============================
print("\n📊 Evaluation Results:")
print(f"   ➤ Top-1 Accuracy       : {top1*100:.2f}%")
print(f"   ➤ Top-5 Accuracy       : {top5*100:.2f}%")
print(f"   ➤ Balanced Accuracy    : {bal_acc*100:.2f}%")
print(f"   ➤ Macro F1-Score       : {f1:.4f}")
print(f"   ➤ Equal Error Rate (EER): {eer:.4f}")
print(f"   ➤ ROC-AUC (macro)      : {roc_auc:.4f}")

# ==============================
# Plot ROC Curve
# ==============================
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.3f})')
plt.plot([0,1], [0,1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (Test Set)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

print("\n[INFO] Running t-SNE and UMAP visualization...")

from sklearn.manifold import TSNE
try:
    from umap import UMAP
    has_umap = True
except ImportError:
    print("[WARN] UMAP not installed — skipping UMAP visualization.")
    has_umap = False

# ---- t-SNE ----
tsne = TSNE(n_components=2, init='random', random_state=42, perplexity=30)
emb_tsne = tsne.fit_transform(embeddings)

plt.figure(figsize=(7,6))
scatter = plt.scatter(emb_tsne[:,0], emb_tsne[:,1], c=y_true, cmap='tab20', s=10, alpha=0.8)
plt.title("t-SNE of ArcFace Embeddings (Test Set)")
plt.colorbar(scatter, label="Class")
plt.tight_layout()
plt.show()

# ---- UMAP ----
if has_umap:
    reducer = UMAP(n_components=2, random_state=42, n_neighbors=15, min_dist=0.1)
    emb_umap = reducer.fit_transform(embeddings)

    plt.figure(figsize=(7,6))
    scatter = plt.scatter(emb_umap[:,0], emb_umap[:,1], c=y_true, cmap='tab20', s=10, alpha=0.8)
    plt.title("UMAP of ArcFace Embeddings (Test Set)")
    plt.colorbar(scatter, label="Class")
    plt.tight_layout()
    plt.show()
# Out:
# Found 550 files belonging to 455 classes.
# [INFO] Loading trained ArcFace model from: C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\1_adamW_best_arcface_model.keras
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# c:\Users\Amrit Shah\Desktop\Muzzle based Identification\env\Lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# 📊 Evaluation Results:
#    ➤ Top-1 Accuracy       : 86.55%
#    ➤ Top-5 Accuracy       : 94.18%
#    ➤ Balanced Accuracy    : 84.49%
#    ➤ Macro F1-Score       : 0.8087
#    ➤ Equal Error Rate (EER): 0.0370
#    ➤ ROC-AUC (macro)      : 0.9880
# [INFO] Running t-SNE and UMAP visualization...
# [WARN] UMAP not installed — skipping UMAP visualization.

# %% [markdown]
# For dataset 2

# %%
#!/usr/bin/env python3
"""
train_arcface_finetune_true.py
True ArcFace fine-tuning with ResNet50 backbone,
Top-1 and Top-5 metrics, and plotted training curves.
"""
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
from tensorflow.keras import layers
from sklearn.utils.class_weight import compute_class_weight



# ==============================
# USER CONFIG
# ==============================
OUTPUT_DIR = r"C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify"
train_dir  = r"C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\preprocess_dataset_2\train"
val_dir    = r"C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\preprocess_dataset_2\val"


PK_P, PK_K = 16, 4
IMG_SIZE   = (224, 224)
BATCH_SIZE = PK_P * PK_K

# ==============================
# Dataset
# ==============================
train_augment = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.03),
    layers.RandomZoom(0.05),
    layers.RandomContrast(0.1)
])


def preprocess_rgb(x, y):
    # convert grayscale -> RGB if needed
    x = tf.image.grayscale_to_rgb(x) if x.shape[-1] == 1 else x
    return x, y

train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir, labels='inferred', label_mode='int',
    image_size=IMG_SIZE, batch_size=BATCH_SIZE, shuffle=True,
    color_mode='rgb'  # <-- ensure it's loaded as 3-channel
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    val_dir, labels='inferred', label_mode='int',
    image_size=IMG_SIZE, batch_size=BATCH_SIZE, shuffle=False,
    color_mode='rgb'
)

class_names = train_ds.class_names
num_classes = len(class_names)
print(f"Found {num_classes} unique classes.")


AUTOTUNE = tf.data.AUTOTUNE
train_ds = (
    train_ds
    .map(preprocess_rgb)
    .map(lambda x, y: (train_augment(x, training=True), y))
    .map(lambda x, y: ((x, y), y))
    .prefetch(AUTOTUNE)   # ✅ at the END
)

val_ds = (
    val_ds
    .map(preprocess_rgb)
    .map(lambda x, y: ((x, y), y))
    .prefetch(AUTOTUNE)   # ✅ at the END
)


# --- compute all labels from the training dataset ---
all_labels = np.array([label.numpy() for (x, y), label in train_ds.unbatch()])


# --- compute class weights automatically ---
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(num_classes),
    y=all_labels
)

# --- convert to dictionary for Keras ---
class_weights = dict(enumerate(class_weights))


# ==============================
# 🧠 Custom ArcFace Layer
# ==============================
class ArcFace(tf.keras.layers.Layer):
    def __init__(self, num_classes, s=30.0, m=0.35, **kwargs):
        super().__init__(**kwargs)
        self.num_classes = num_classes
        self.s = s
        self.m = m

    def build(self, input_shape):
        self.W = self.add_weight(
            name='W',
            shape=(int(input_shape[-1]), self.num_classes),
            initializer='glorot_uniform',
            trainable=True
        )

    def call(self, inputs, labels):
        x = tf.nn.l2_normalize(inputs, axis=1)
        W = tf.nn.l2_normalize(self.W, axis=0)
        cos_theta = tf.matmul(x, W)
        cos_theta = tf.clip_by_value(cos_theta, -1.0, 1.0)
        theta = tf.acos(cos_theta)
        selected = tf.gather_nd(theta, tf.stack([tf.range(tf.shape(labels)[0]), labels], axis=1))
        theta_y_m = selected + self.m
        mask = tf.one_hot(labels, depth=self.num_classes)
        cos_theta_m = tf.cos(theta_y_m)
        logits = cos_theta * (1 - mask) + cos_theta_m[:, None] * mask
        logits *= self.s
        return logits

# ==============================
# Build True ArcFace Model
# ==============================
base_model = tf.keras.applications.ResNet50(
    include_top=False, weights='imagenet',
    pooling='avg', input_shape=IMG_SIZE + (3,))
base_model.trainable = False

inputs = tf.keras.Input(shape=IMG_SIZE + (3,))
labels = tf.keras.Input(shape=(), dtype=tf.int32)
x = tf.keras.applications.resnet50.preprocess_input(inputs)
x = base_model(x, training=False)
x = tf.keras.layers.Dense(512, activation=None, name="embedding")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.25)(x)
logits = ArcFace(num_classes)(x, labels)
model = tf.keras.Model(inputs=[inputs, labels], outputs=logits, name="arcface_resnet50")

# ==============================
# Callbacks
# ==============================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(OUTPUT_DIR, "2_adamW_best_arcface_model.keras"),
        monitor="val_top1_acc", save_best_only=True, mode="max", verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_top1_acc", factor=0.5, patience=3, verbose=1),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_top1_acc", patience=6, restore_best_weights=True, verbose=1)
]


# ==============================================
# 🧱 STAGE 1 — Freeze backbone (stabilize ArcFace head)
# ==============================================

initial_lr = 2e-4
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile(
    optimizer=tf.keras.optimizers.AdamW(initial_lr, weight_decay=1e-4),
    loss=loss_fn,
    metrics=[
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=1, name="top1_acc"),
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name="top5_acc")
    ]
)


# ==============================
# Train
# ==============================
EPOCHS_1 = 15
history1 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=EPOCHS_1, callbacks=callbacks
    ,class_weight=class_weights
)



# ==============================================
# 🔓 STAGE 2 — Unfreeze backbone (fine-tune entire model)
# ==============================================

print("\n🔓 Stage 2: Unfreezing backbone and fine-tuning entire model...")
N_UNFREEZE = 50  # try 30–70 depending on dataset size

# Freeze all layers first
for layer in base_model.layers:
    layer.trainable = False

# Unfreeze last N layers (but skip BN layers)
for layer in base_model.layers[-N_UNFREEZE:]:
    if not isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = True

# 🔒 Keep all BatchNorm layers frozen globally
for layer in base_model.layers:
    if isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = False


model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-5, weight_decay=5e-5),
    loss=loss_fn,
    metrics=[
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=1, name="top1_acc"),
        tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5, name="top5_acc")
    ]
)

EPOCHS_2 = 25
total_epochs = EPOCHS_1 + EPOCHS_2

history2 = model.fit(
    train_ds, validation_data=val_ds,
    epochs=total_epochs,
    initial_epoch=EPOCHS_1,
    callbacks=callbacks ,class_weight=class_weights
)

# Combine histories for full plot
def merge_histories(h1, h2):
    # handle both Keras History objects and dicts
    h1 = h1.history if hasattr(h1, "history") else h1
    h2 = h2.history if hasattr(h2, "history") else h2

    hist = {}
    for k in h1.keys():
        hist[k] = h1[k] + h2[k]
    return hist

full_history = merge_histories(history1, history2)



# ==============================
# Plot training graphs
# ==============================
def plot_history(history_dict, out_dir):
    epochs = np.arange(1, len(history_dict['loss']) + 1)
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.plot(epochs, history_dict['loss'], label='train_loss')
    plt.plot(epochs, history_dict['val_loss'], label='val_loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.grid(True)
    plt.subplot(1,2,2)
    plt.plot(epochs, history_dict['top1_acc'], label='train_top1')
    plt.plot(epochs, history_dict['val_top1_acc'], label='val_top1')
    plt.plot(epochs, history_dict['top5_acc'], label='train_top5', linestyle='--')
    plt.plot(epochs, history_dict['val_top5_acc'], label='val_top5', linestyle='--')
    plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.grid(True)
    plt.tight_layout()
    plot_path = os.path.join(out_dir, "2_adamW_training_history.png")
    plt.savefig(plot_path, dpi=200)
    plt.close()
    print(f"[save] training plot: {plot_path}")

plot_history(full_history, OUTPUT_DIR)

print("\n✅ Training completed. Best model saved as '2_adamW_best_arcface_model.keras'.")
print(f"Training history plot saved to: {os.path.join(OUTPUT_DIR, '2_adamW_training_history.png')}")
# Out:
# Found 3725 files belonging to 268 classes.
# Found 623 files belonging to 268 classes.
# Found 268 unique classes.
# Epoch 1/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 15.5905 - top1_acc: 0.0000e+00 - top5_acc: 0.0000e+00
# Epoch 1: val_top1_acc improved from None to 0.00000, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - loss: 14.7785 - top1_acc: 0.0000e+00 - top5_acc: 0.0000e+00 - val_loss: 13.6266 - val_top1_acc: 0.0000e+00 - val_top5_acc: 0.0000e+00 - learning_rate: 2.0000e-04
# Epoch 2/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 12.1382 - top1_acc: 0.0000e+00 - top5_acc: 5.9712e-05
# Epoch 2: val_top1_acc did not improve from 0.00000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - loss: 11.7223 - top1_acc: 0.0000e+00 - top5_acc: 2.6846e-04 - val_loss: 11.0452 - val_top1_acc: 0.0000e+00 - val_top5_acc: 0.0000e+00 - learning_rate: 2.0000e-04
# Epoch 3/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 9.8026 - top1_acc: 1.1331e-04 - top5_acc: 0.0017
# Epoch 3: val_top1_acc improved from 0.00000 to 0.00803, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - loss: 9.4452 - top1_acc: 0.0011 - top5_acc: 0.0054 - val_loss: 8.7408 - val_top1_acc: 0.0080 - val_top5_acc: 0.0225 - learning_rate: 2.0000e-04
# Epoch 4/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 7.9314 - top1_acc: 0.0101 - top5_acc: 0.0362
# Epoch 4: val_top1_acc improved from 0.00803 to 0.04655, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - loss: 7.5820 - top1_acc: 0.0188 - top5_acc: 0.0596 - val_loss: 6.7858 - val_top1_acc: 0.0465 - val_top5_acc: 0.1413 - learning_rate: 2.0000e-04
# Epoch 5/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.2201 - top1_acc: 0.0642 - top5_acc: 0.1690
# Epoch 5: val_top1_acc improved from 0.04655 to 0.15891, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - loss: 6.0387 - top1_acc: 0.0878 - top5_acc: 0.2048 - val_loss: 5.4186 - val_top1_acc: 0.1589 - val_top5_acc: 0.3419 - learning_rate: 2.0000e-04
# Epoch 6/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.9346 - top1_acc: 0.1786 - top5_acc: 0.3566
# Epoch 6: val_top1_acc improved from 0.15891 to 0.29374, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 195s 3s/step - loss: 4.8043 - top1_acc: 0.2035 - top5_acc: 0.3858 - val_loss: 4.3055 - val_top1_acc: 0.2937 - val_top5_acc: 0.5201 - learning_rate: 2.0000e-04
# Epoch 7/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3.8916 - top1_acc: 0.3111 - top5_acc: 0.5234
# Epoch 7: val_top1_acc improved from 0.29374 to 0.42055, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - loss: 3.8968 - top1_acc: 0.3297 - top5_acc: 0.5345 - val_loss: 3.5715 - val_top1_acc: 0.4205 - val_top5_acc: 0.6035 - learning_rate: 2.0000e-04
# Epoch 8/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3.1785 - top1_acc: 0.4169 - top5_acc: 0.6323
# Epoch 8: val_top1_acc improved from 0.42055 to 0.53130, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - loss: 3.1527 - top1_acc: 0.4330 - top5_acc: 0.6387 - val_loss: 2.8888 - val_top1_acc: 0.5313 - val_top5_acc: 0.6902 - learning_rate: 2.0000e-04
# Epoch 9/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 2.6224 - top1_acc: 0.5174 - top5_acc: 0.7151
# Epoch 9: val_top1_acc improved from 0.53130 to 0.58266, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 196s 3s/step - loss: 2.6454 - top1_acc: 0.5213 - top5_acc: 0.7219 - val_loss: 2.4242 - val_top1_acc: 0.5827 - val_top5_acc: 0.7528 - learning_rate: 2.0000e-04
# Epoch 10/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 2.2195 - top1_acc: 0.5881 - top5_acc: 0.7752
# Epoch 10: val_top1_acc improved from 0.58266 to 0.62119, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 195s 3s/step - loss: 2.2269 - top1_acc: 0.5968 - top5_acc: 0.7766 - val_loss: 2.1907 - val_top1_acc: 0.6212 - val_top5_acc: 0.7994 - learning_rate: 2.0000e-04
# Epoch 11/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.8695 - top1_acc: 0.6575 - top5_acc: 0.8241
# Epoch 11: val_top1_acc improved from 0.62119 to 0.66132, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - loss: 1.8895 - top1_acc: 0.6556 - top5_acc: 0.8231 - val_loss: 1.9370 - val_top1_acc: 0.6613 - val_top5_acc: 0.8299 - learning_rate: 2.0000e-04
# Epoch 12/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.6394 - top1_acc: 0.7007 - top5_acc: 0.8586
# Epoch 12: val_top1_acc improved from 0.66132 to 0.70787, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - loss: 1.6798 - top1_acc: 0.6999 - top5_acc: 0.8523 - val_loss: 1.7082 - val_top1_acc: 0.7079 - val_top5_acc: 0.8539 - learning_rate: 2.0000e-04
# Epoch 13/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.4249 - top1_acc: 0.7383 - top5_acc: 0.8807
# Epoch 13: val_top1_acc improved from 0.70787 to 0.72392, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - loss: 1.4684 - top1_acc: 0.7361 - top5_acc: 0.8709 - val_loss: 1.5650 - val_top1_acc: 0.7239 - val_top5_acc: 0.8620 - learning_rate: 2.0000e-04
# Epoch 14/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.2823 - top1_acc: 0.7662 - top5_acc: 0.8914
# Epoch 14: val_top1_acc improved from 0.72392 to 0.75441, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - loss: 1.2900 - top1_acc: 0.7675 - top5_acc: 0.8934 - val_loss: 1.4449 - val_top1_acc: 0.7544 - val_top5_acc: 0.8828 - learning_rate: 2.0000e-04
# Epoch 15/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.1908 - top1_acc: 0.7874 - top5_acc: 0.9026
# Epoch 15: val_top1_acc improved from 0.75441 to 0.76404, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - loss: 1.1797 - top1_acc: 0.7887 - top5_acc: 0.9052 - val_loss: 1.3678 - val_top1_acc: 0.7640 - val_top5_acc: 0.8925 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 15.
#
# 🔓 Stage 2: Unfreezing backbone and fine-tuning entire model...
# Epoch 16/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.9768 - top1_acc: 0.8219 - top5_acc: 0.9276
# Epoch 16: val_top1_acc improved from 0.76404 to 0.81220, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 285s 5s/step - loss: 0.9635 - top1_acc: 0.8298 - top5_acc: 0.9267 - val_loss: 1.0753 - val_top1_acc: 0.8122 - val_top5_acc: 0.9165 - learning_rate: 1.0000e-05
# Epoch 17/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.7368 - top1_acc: 0.8698 - top5_acc: 0.9442
# Epoch 17: val_top1_acc improved from 0.81220 to 0.84270, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 273s 5s/step - loss: 0.7725 - top1_acc: 0.8690 - top5_acc: 0.9431 - val_loss: 0.9603 - val_top1_acc: 0.8427 - val_top5_acc: 0.9278 - learning_rate: 1.0000e-05
# Epoch 18/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.6064 - top1_acc: 0.8952 - top5_acc: 0.9581
# Epoch 18: val_top1_acc improved from 0.84270 to 0.85393, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 272s 5s/step - loss: 0.6433 - top1_acc: 0.8915 - top5_acc: 0.9557 - val_loss: 0.8951 - val_top1_acc: 0.8539 - val_top5_acc: 0.9454 - learning_rate: 1.0000e-05
# Epoch 19/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.5702 - top1_acc: 0.9018 - top5_acc: 0.9639
# Epoch 19: val_top1_acc improved from 0.85393 to 0.86998, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 273s 5s/step - loss: 0.5857 - top1_acc: 0.9007 - top5_acc: 0.9632 - val_loss: 0.8048 - val_top1_acc: 0.8700 - val_top5_acc: 0.9470 - learning_rate: 1.0000e-05
# Epoch 20/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.5039 - top1_acc: 0.9137 - top5_acc: 0.9680
# Epoch 20: val_top1_acc improved from 0.86998 to 0.88443, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 272s 5s/step - loss: 0.5322 - top1_acc: 0.9101 - top5_acc: 0.9670 - val_loss: 0.7571 - val_top1_acc: 0.8844 - val_top5_acc: 0.9583 - learning_rate: 1.0000e-05
# Epoch 21/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.4568 - top1_acc: 0.9214 - top5_acc: 0.9699
# Epoch 21: val_top1_acc improved from 0.88443 to 0.88604, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 272s 5s/step - loss: 0.4829 - top1_acc: 0.9221 - top5_acc: 0.9691 - val_loss: 0.7248 - val_top1_acc: 0.8860 - val_top5_acc: 0.9599 - learning_rate: 1.0000e-05
# Epoch 22/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.4032 - top1_acc: 0.9360 - top5_acc: 0.9794
# Epoch 22: val_top1_acc improved from 0.88604 to 0.89406, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 272s 5s/step - loss: 0.4453 - top1_acc: 0.9275 - top5_acc: 0.9769 - val_loss: 0.6811 - val_top1_acc: 0.8941 - val_top5_acc: 0.9615 - learning_rate: 1.0000e-05
# Epoch 23/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.3877 - top1_acc: 0.9383 - top5_acc: 0.9783
# Epoch 23: val_top1_acc improved from 0.89406 to 0.90048, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 272s 5s/step - loss: 0.4054 - top1_acc: 0.9348 - top5_acc: 0.9772 - val_loss: 0.6407 - val_top1_acc: 0.9005 - val_top5_acc: 0.9695 - learning_rate: 1.0000e-05
# Epoch 24/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.3488 - top1_acc: 0.9423 - top5_acc: 0.9794
# Epoch 24: val_top1_acc improved from 0.90048 to 0.90369, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 275s 5s/step - loss: 0.3684 - top1_acc: 0.9420 - top5_acc: 0.9799 - val_loss: 0.6122 - val_top1_acc: 0.9037 - val_top5_acc: 0.9663 - learning_rate: 1.0000e-05
# Epoch 25/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.2908 - top1_acc: 0.9607 - top5_acc: 0.9855
# Epoch 25: val_top1_acc improved from 0.90369 to 0.91493, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 285s 5s/step - loss: 0.3337 - top1_acc: 0.9514 - top5_acc: 0.9844 - val_loss: 0.5971 - val_top1_acc: 0.9149 - val_top5_acc: 0.9727 - learning_rate: 1.0000e-05
# Epoch 26/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.3031 - top1_acc: 0.9522 - top5_acc: 0.9866
# Epoch 26: val_top1_acc improved from 0.91493 to 0.91814, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 277s 5s/step - loss: 0.3240 - top1_acc: 0.9544 - top5_acc: 0.9855 - val_loss: 0.5638 - val_top1_acc: 0.9181 - val_top5_acc: 0.9711 - learning_rate: 1.0000e-05
# Epoch 27/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.2888 - top1_acc: 0.9517 - top5_acc: 0.9839
# Epoch 27: val_top1_acc did not improve from 0.91814
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 276s 5s/step - loss: 0.2955 - top1_acc: 0.9514 - top5_acc: 0.9852 - val_loss: 0.5597 - val_top1_acc: 0.9181 - val_top5_acc: 0.9695 - learning_rate: 1.0000e-05
# Epoch 28/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.2673 - top1_acc: 0.9592 - top5_acc: 0.9841
# Epoch 28: val_top1_acc improved from 0.91814 to 0.92135, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 281s 5s/step - loss: 0.2805 - top1_acc: 0.9592 - top5_acc: 0.9863 - val_loss: 0.5306 - val_top1_acc: 0.9213 - val_top5_acc: 0.9759 - learning_rate: 1.0000e-05
# Epoch 29/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.2246 - top1_acc: 0.9693 - top5_acc: 0.9896
# Epoch 29: val_top1_acc did not improve from 0.92135
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 282s 5s/step - loss: 0.2345 - top1_acc: 0.9662 - top5_acc: 0.9903 - val_loss: 0.5113 - val_top1_acc: 0.9181 - val_top5_acc: 0.9711 - learning_rate: 1.0000e-05
# Epoch 30/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.2417 - top1_acc: 0.9652 - top5_acc: 0.9872
# Epoch 30: val_top1_acc improved from 0.92135 to 0.93740, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 284s 5s/step - loss: 0.2341 - top1_acc: 0.9662 - top5_acc: 0.9893 - val_loss: 0.5153 - val_top1_acc: 0.9374 - val_top5_acc: 0.9743 - learning_rate: 1.0000e-05
# Epoch 31/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.2015 - top1_acc: 0.9701 - top5_acc: 0.9921
# Epoch 31: val_top1_acc did not improve from 0.93740
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 271s 5s/step - loss: 0.2267 - top1_acc: 0.9686 - top5_acc: 0.9903 - val_loss: 0.5324 - val_top1_acc: 0.9246 - val_top5_acc: 0.9743 - learning_rate: 1.0000e-05
# Epoch 32/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.1832 - top1_acc: 0.9717 - top5_acc: 0.9919
# Epoch 32: val_top1_acc improved from 0.93740 to 0.94222, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 272s 5s/step - loss: 0.2073 - top1_acc: 0.9702 - top5_acc: 0.9925 - val_loss: 0.4770 - val_top1_acc: 0.9422 - val_top5_acc: 0.9791 - learning_rate: 1.0000e-05
# Epoch 33/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.1675 - top1_acc: 0.9771 - top5_acc: 0.9933
# Epoch 33: val_top1_acc did not improve from 0.94222
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 271s 5s/step - loss: 0.1952 - top1_acc: 0.9753 - top5_acc: 0.9925 - val_loss: 0.4622 - val_top1_acc: 0.9374 - val_top5_acc: 0.9791 - learning_rate: 1.0000e-05
# Epoch 34/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.1660 - top1_acc: 0.9778 - top5_acc: 0.9935
# Epoch 34: val_top1_acc did not improve from 0.94222
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 270s 5s/step - loss: 0.1790 - top1_acc: 0.9764 - top5_acc: 0.9930 - val_loss: 0.4604 - val_top1_acc: 0.9422 - val_top5_acc: 0.9775 - learning_rate: 1.0000e-05
# Epoch 35/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.1561 - top1_acc: 0.9786 - top5_acc: 0.9912
# Epoch 35: val_top1_acc did not improve from 0.94222
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 269s 5s/step - loss: 0.1754 - top1_acc: 0.9766 - top5_acc: 0.9925 - val_loss: 0.4835 - val_top1_acc: 0.9310 - val_top5_acc: 0.9807 - learning_rate: 1.0000e-05
# Epoch 36/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.1609 - top1_acc: 0.9777 - top5_acc: 0.9928
# Epoch 36: val_top1_acc improved from 0.94222 to 0.94543, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 273s 5s/step - loss: 0.1549 - top1_acc: 0.9791 - top5_acc: 0.9944 - val_loss: 0.4493 - val_top1_acc: 0.9454 - val_top5_acc: 0.9807 - learning_rate: 5.0000e-06
# Epoch 37/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.1394 - top1_acc: 0.9857 - top5_acc: 0.9921
# Epoch 37: val_top1_acc did not improve from 0.94543
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 271s 5s/step - loss: 0.1430 - top1_acc: 0.9850 - top5_acc: 0.9941 - val_loss: 0.4226 - val_top1_acc: 0.9454 - val_top5_acc: 0.9807 - learning_rate: 5.0000e-06
# Epoch 38/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.1382 - top1_acc: 0.9848 - top5_acc: 0.9946
# Epoch 38: val_top1_acc did not improve from 0.94543
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 274s 5s/step - loss: 0.1349 - top1_acc: 0.9831 - top5_acc: 0.9957 - val_loss: 0.4198 - val_top1_acc: 0.9406 - val_top5_acc: 0.9823 - learning_rate: 5.0000e-06
# Epoch 39/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.1452 - top1_acc: 0.9820 - top5_acc: 0.9932
# Epoch 39: val_top1_acc improved from 0.94543 to 0.94703, saving model to C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 273s 5s/step - loss: 0.1407 - top1_acc: 0.9826 - top5_acc: 0.9954 - val_loss: 0.4314 - val_top1_acc: 0.9470 - val_top5_acc: 0.9807 - learning_rate: 5.0000e-06
# Epoch 40/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.1075 - top1_acc: 0.9839 - top5_acc: 0.9981
# Epoch 40: val_top1_acc did not improve from 0.94703
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 271s 5s/step - loss: 0.1205 - top1_acc: 0.9834 - top5_acc: 0.9968 - val_loss: 0.4160 - val_top1_acc: 0.9470 - val_top5_acc: 0.9791 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 39.
# [save] training plot: C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_training_history.png
#
# ✅ Training completed. Best model saved as '2_adamW_best_arcface_model.keras'.
# Training history plot saved to: C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_training_history.png

# %%
#!/usr/bin/env python3
"""
evaluate_arcface_metrics.py
Loads ArcFace-trained model, extracts embeddings,
and computes Top-K, ROC, EER, Balanced Accuracy, F1, and Recall on TEST dataset.
"""

import tensorflow as tf
import numpy as np
import os
from sklearn.metrics import roc_curve, auc, f1_score, balanced_accuracy_score, recall_score
import matplotlib.pyplot as plt

# ==============================
# USER CONFIG
# ==============================
MODEL_PATH = r"C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras"
test_dir   = r"C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\preprocess_dataset_2\test"
IMG_SIZE   = (224, 224)
BATCH_SIZE = 32

# ==============================
# Load dataset
# ==============================
def preprocess_rgb(x, y):
    x = tf.image.grayscale_to_rgb(x) if x.shape[-1] == 1 else x
    return x, y

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir, labels='inferred', label_mode='int',
    image_size=IMG_SIZE, batch_size=BATCH_SIZE, shuffle=False, color_mode='rgb'
)
class_names = test_ds.class_names
num_classes = len(class_names)

AUTOTUNE = tf.data.AUTOTUNE
test_ds = test_ds.map(preprocess_rgb).prefetch(AUTOTUNE)

# ==============================
# Load full ArcFace model
# ==============================
print(f"[INFO] Loading trained ArcFace model from: {MODEL_PATH}")
# ==============================
# 🧠 ArcFace layer (same as training)
# ==============================
import tensorflow as tf

class ArcFace(tf.keras.layers.Layer):
    def __init__(self, num_classes, s=30.0, m=0.5, **kwargs):
        super().__init__(**kwargs)
        self.num_classes = num_classes
        self.s = s
        self.m = m

    def build(self, input_shape):
        self.W = self.add_weight(
            name='W',
            shape=(int(input_shape[-1]), self.num_classes),
            initializer='glorot_uniform',
            trainable=True
        )

    def call(self, inputs, labels):
        x = tf.nn.l2_normalize(inputs, axis=1)
        W = tf.nn.l2_normalize(self.W, axis=0)
        cos_theta = tf.matmul(x, W)
        cos_theta = tf.clip_by_value(cos_theta, -1.0, 1.0)
        theta = tf.acos(cos_theta)
        selected = tf.gather_nd(theta, tf.stack([tf.range(tf.shape(labels)[0]), labels], axis=1))
        theta_y_m = selected + self.m
        mask = tf.one_hot(labels, depth=self.num_classes)
        cos_theta_m = tf.cos(theta_y_m)
        logits = cos_theta * (1 - mask) + cos_theta_m[:, None] * mask
        logits *= self.s
        return logits
 
# ==============================
# Build inference (embedding) model
# ==============================
from tensorflow.keras.models import Model

# Full loaded model
full_model = tf.keras.models.load_model(MODEL_PATH, custom_objects={"ArcFace": ArcFace})

# Build embedding model: input = image, output = batch normalization (embedding)
embedding_model = Model(
    inputs=full_model.input[0],                        # image input only
    outputs=full_model.get_layer("batch_normalization_3").output
)


# ==============================
# Get predictions
# ==============================
y_true = []
embeddings = []
for batch_x, batch_y in test_ds:
    emb = embedding_model(batch_x, training=False)
    embeddings.append(emb.numpy())
    y_true.append(batch_y.numpy())

embeddings = np.concatenate(embeddings)
y_true = np.concatenate(y_true)

# Compute cosine similarities as logits (simple classification)
W = full_model.get_layer("arc_face_1").W.numpy()  # ArcFace class weights
W = W / np.linalg.norm(W, axis=0, keepdims=True)
emb_norm = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)
logits = np.dot(emb_norm, W)

y_pred = np.argmax(logits, axis=1)
y_score = tf.nn.softmax(logits, axis=1).numpy()

# ==============================
# Compute metrics
# ==============================
# Top-1 & Top-5
top1 = np.mean(np.equal(y_true, np.argmax(y_score, axis=1)))
top5 = np.mean([y_true[i] in np.argsort(y_score[i])[-5:] for i in range(len(y_true))])

# ROC & AUC (macro average)
fpr, tpr, _ = roc_curve(tf.keras.utils.to_categorical(y_true, num_classes).ravel(),
                        y_score.ravel())
roc_auc = auc(fpr, tpr)

# EER
fnr = 1 - tpr
eer_threshold = fpr[np.nanargmin(np.absolute((fnr - fpr)))]
eer = fpr[np.nanargmin(np.absolute((fnr - fpr)))]

# Other metrics
bal_acc = balanced_accuracy_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average=None)

# ==============================
# Print metrics
# ==============================
print("\n📊 Evaluation Results:")
print(f"   ➤ Top-1 Accuracy       : {top1*100:.2f}%")
print(f"   ➤ Top-5 Accuracy       : {top5*100:.2f}%")
print(f"   ➤ Balanced Accuracy    : {bal_acc*100:.2f}%")
print(f"   ➤ Macro F1-Score       : {f1:.4f}")
print(f"   ➤ Equal Error Rate (EER): {eer:.4f}")
print(f"   ➤ ROC-AUC (macro)      : {roc_auc:.4f}")

# ==============================
# Plot ROC Curve
# ==============================
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.3f})')
plt.plot([0,1], [0,1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (Test Set)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

print("\n[INFO] Running t-SNE and UMAP visualization...")

from sklearn.manifold import TSNE
try:
    from umap import UMAP
    has_umap = True
except ImportError:
    print("[WARN] UMAP not installed — skipping UMAP visualization.")
    has_umap = False

# ---- t-SNE ----
tsne = TSNE(n_components=2, init='random', random_state=42, perplexity=30)
emb_tsne = tsne.fit_transform(embeddings)

plt.figure(figsize=(7,6))
scatter = plt.scatter(emb_tsne[:,0], emb_tsne[:,1], c=y_true, cmap='tab20', s=10, alpha=0.8)
plt.title("t-SNE of ArcFace Embeddings (Test Set)")
plt.colorbar(scatter, label="Class")
plt.tight_layout()
plt.show()

# ---- UMAP ----
if has_umap:
    reducer = UMAP(n_components=2, random_state=42, n_neighbors=15, min_dist=0.1)
    emb_umap = reducer.fit_transform(embeddings)

    plt.figure(figsize=(7,6))
    scatter = plt.scatter(emb_umap[:,0], emb_umap[:,1], c=y_true, cmap='tab20', s=10, alpha=0.8)
    plt.title("UMAP of ArcFace Embeddings (Test Set)")
    plt.colorbar(scatter, label="Class")
    plt.tight_layout()
    plt.show()
# Out:
# Found 972 files belonging to 268 classes.
# [INFO] Loading trained ArcFace model from: C:\Users\Amrit Shah\Desktop\Muzzle based Identification\DL\arcface_modify\2_adamW_best_arcface_model.keras
#
# 📊 Evaluation Results:
#    ➤ Top-1 Accuracy       : 98.56%
#    ➤ Top-5 Accuracy       : 99.69%
#    ➤ Balanced Accuracy    : 97.99%
#    ➤ Macro F1-Score       : 0.9775
#    ➤ Equal Error Rate (EER): 0.0014
#    ➤ ROC-AUC (macro)      : 0.9997
# [INFO] Running t-SNE and UMAP visualization...
# [WARN] UMAP not installed — skipping UMAP visualization.
